# %% [markdown]
# <a href="https://colab.research.google.com/github/Gt3Joo/Gt3Joo/blob/main/TrabalhoA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
anime = pd.read_csv('/content/drive/MyDrive/TrabalhoA3/anime.csv')
movie = pd.read_csv('/content/drive/MyDrive/TrabalhoA3/TMDB_movie_dataset_v11.csv')
manga = pd.read_csv('/content/drive/MyDrive/TrabalhoA3/manga.csv')

# %% [markdown]
# Anime

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24985 non-null  int64
#  1   title             24985 non-null  object
#  2   type              24927 non-null  object
#  3   score             16050 non-null  float64
#  4   scored_by         24985 non-null  int64
#  5   status            24985 non-null  object
#  6   episodes          24438 non-null  float64
#  7   start_date        24110 non-null  object
#  8   end_date          22215 non-null  object
#  9   source            21424 non-null  object
#  10  members           24985 non-null  int64
#  11  favorites         24985 non-null  int64
#  12  episode_duration  24387 non-null  object
#  13  total_duration    24162 non-null  object
#  14  rating            24405 non-null  object
#  15  sfw               24985 non-null  bool
# ...

# %%
anime.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# ...

# %%
anime.tail()
# Out:
#        anime_id                 title   type  score  scored_by  \
# 24980     54574               Seizoki  movie    NaN         10
# 24981     56159             Kanshajou  music    NaN          2
# 24982     56107  Kaijuu Sekai Seifuku    ona    NaN          2
# 24983     56168   Yotsukado no Melody  music    NaN          1
# 24984     56202         Ame to Kusari  music    NaN          0
#
#                  status  episodes  start_date    end_date     source  ...  \
# 24980   finished_airing       1.0  1964-01-01  1964-01-01   original  ...
# 24981   finished_airing       1.0  1993-02-02  1993-02-02   original  ...
# 24982  currently_airing       NaN  2020-04-02         NaN  web_manga  ...
# 24983   finished_airing       1.0  2014-12-01  2014-12-01   original  ...
# 24984   finished_airing       1.0  2015-08-05  2015-08-05   original  ...
#
#        producers  licensors  \
# 24980         []         []
# 24981    ['NHK']         []
# 24982         []         []
# ...

# %%
anime
# Out:
#        anime_id                               title   type  score  scored_by  \
# 0          5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1         11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2         38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3          9253                         Steins;Gate     tv   9.07    1348232
# 4         28851                      Koe no Katachi  movie   8.94    1540277
# ...         ...                                 ...    ...    ...        ...
# 24980     54574                             Seizoki  movie    NaN         10
# 24981     56159                           Kanshajou  music    NaN          2
# 24982     56107                Kaijuu Sekai Seifuku    ona    NaN          2
# 24983     56168                 Yotsukado no Melody  music    NaN          1
# 24984     56202                       Ame to Kusari  music    NaN          0
#
# ...

# %%
anime['score'].unique()
# Out:
# array([9.1 , 9.04, 9.05, 9.07, 8.94, 8.84, 8.91, 8.8 , 8.78, 8.7 , 8.62,
#        8.63, 8.65, 8.54, 8.75, 8.79, 8.67, 8.5 , 8.51, 8.74, 8.66, 8.61,
#        8.93, 8.64, 8.77, 8.6 , 8.49, 8.44, 8.57, 8.55, 8.58, 8.41, 8.69,
#        8.35, 8.56, 8.34, 8.31, 8.87, 8.37, 8.36, 8.26, 8.29, 8.33, 8.23,
#        8.81, 8.45, 8.53, 8.24, 8.39, 8.28, 8.47, 8.32, 8.43, 8.25, 8.83,
#        8.48, 8.76, 8.46, 8.42, 8.72, 8.2 , 8.3 , 9.06, 8.89, 8.21, 8.15,
#        8.11, 8.19, 8.16, 8.71, 8.22, 8.38, 8.14, 9.  , 8.08, 8.09, 8.17,
#        8.06, 8.1 , 8.04, 8.88, 8.27, 8.68, 7.99, 8.52, 8.07, 8.01, 9.03,
#        8.  , 7.95, 7.97, 8.02, 8.03, 7.98, 7.92, 7.96, 7.89, 8.4 , 8.98,
#        7.9 , 7.91, 8.13, 8.18, 7.94, 7.86, 8.05, 7.84, 7.79, 7.85, 7.93,
#        7.82, 7.83, 8.73, 8.85, 7.75, 7.76, 7.88, 7.81, 7.87, 7.74, 7.71,
#        7.73, 7.66, 9.02, 7.69, 7.77, 7.72, 7.8 , 7.65, 7.64, 7.61, 7.7 ,
#        7.62, 7.57, 7.58, 7.67, 7.78, 7.55, 7.56, 7.6 , 7.68, 7.5 , 7.49,
# ...

# %%
anime['genres'] = anime['genres'].str.replace('[\[\]\'\"]', '', regex=True)

anime['genres'] = anime['genres'].str.split(', ')
anime = anime.explode('genres')
anime['genres'] = anime['genres'].str.split(',')
anime = anime.explode('genres')
anime = anime[~anime['genres'].str.contains('Hentai|Boys Love|Girls Love|Erotica')]

# %%
anime['genres'].value_counts().to_frame('Quantidade')
# Out:
#                Quantidade
# Comedy               7154
# Fantasy              5326
#                      4988
# Action               4744
# Adventure            3841
# Sci-Fi               3108
# Drama                2839
# Romance              2065
# Slice of Life        1701
# Supernatural         1489
# Mystery               846
# Avant Garde           809
# Ecchi                 790
# Sports                766
# Horror                535
# Suspense              247
# Award Winning         240
# Gourmet               149

# %%
anime['genres'].value_counts()[:10].plot(kind='barh')
# Out:
# <Axes: >

# %%
anime['genres'].value_counts()
# Out:
# Comedy           7154
# Fantasy          5326
#                  4988
# Action           4744
# Adventure        3841
# Sci-Fi           3108
# Drama            2839
# Romance          2065
# Slice of Life    1701
# Supernatural     1489
# Mystery           846
# Avant Garde       809
# Ecchi             790
# Sports            766
# Horror            535
# Suspense          247
# Award Winning     240
# Gourmet           149
# Name: genres, dtype: int64

# %% [markdown]
# Movie

# %%
movie = pd.read_csv('/content/drive/MyDrive/TrabalhoA3/TMDB_movie_dataset_v11.csv')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945123 entries, 0 to 945122
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    945123 non-null  int64
#  1   title                 945112 non-null  object
#  2   vote_average          945123 non-null  float64
#  3   vote_count            945123 non-null  int64
#  4   status                945123 non-null  object
#  5   release_date          857525 non-null  object
#  6   revenue               945123 non-null  int64
#  7   runtime               945123 non-null  int64
#  8   adult                 945123 non-null  bool
#  9   backdrop_path         277265 non-null  object
#  10  budget                945123 non-null  int64
#  11  homepage              102996 non-null  object
#  12  imdb_id               555659 non-null  object
#  13  original_language     945123 non-null  object
# ...

# %%
movie.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#    original_language   original_title  \
# 0                 en        Inception
# ...

# %%
movie['genres'].unique
# Out:
# <bound method Series.unique of 0                  Action, Science Fiction, Adventure
# 1                   Adventure, Drama, Science Fiction
# 2                      Drama, Action, Crime, Thriller
# 3         Action, Adventure, Fantasy, Science Fiction
# 4                  Science Fiction, Action, Adventure
#                              ...
# 945118                                          Drama
# 945119                                         Comedy
# 945120                          Horror, Drama, Comedy
# 945121                                            NaN
# 945122                                         Horror
# Name: genres, Length: 945123, dtype: object>

# %%
movie['genres'] = movie['genres'].str.replace('[\[\]\'\"]', '', regex=True)
movie['genres'] = movie['genres'].str.split(',')
movie = movie.explode('genres')
movie['genres'] = movie['genres'].str.split(' & ')
movie = movie.explode('genres')
movie['genres'] = movie['genres'].str.split(', ')
movie = movie.explode('genres')

# %%
movie['genres'].value_counts().to_frame('Quantidade')
# Out:
#                   Quantidade
# Drama                 149577
# Documentary           136025
# Comedy                 90673
#  Drama                 56297
# Animation              43084
#  Comedy                36348
#  Romance               31400
# Horror                 30129
# Music                  30001
# Action                 27077
#  Thriller              26100
# Romance                17916
#  Crime                 16660
#  TV Movie              16593
#  Family                16350
# Thriller               15451
#  Music                 14170
# Crime                  14113
#  Horror                13932
#  Action                13530
#  Fantasy               13416
#  Adventure             12832
#  Mystery               12087
#  History               11324
#  Science Fiction       11046
# Family                  9484
# Adventure               8563
#  Documentary            8528
# Science Fiction         7783
#  Animation              7522
# Fantasy                 6851
# ...

# %%
movie['genres'].value_counts()[:10].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Mangas

# %%
manga = pd.read_csv('/content/drive/MyDrive/TrabalhoA3/manga.csv')

# %%
manga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64833 entries, 0 to 64832
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manga_id           64833 non-null  int64
#  1   title              64833 non-null  object
#  2   type               64833 non-null  object
#  3   score              24636 non-null  float64
#  4   scored_by          64833 non-null  int64
#  5   status             64833 non-null  object
#  6   volumes            48211 non-null  float64
#  7   chapters           46042 non-null  float64
#  8   start_date         62950 non-null  object
#  9   end_date           51932 non-null  object
#  10  members            64833 non-null  int64
#  11  favorites          64833 non-null  int64
#  12  sfw                64833 non-null  bool
#  13  approved           64833 non-null  bool
#  14  created_at_before  64833 non-null  object
#  15  updated_at         62678 non-null  object
# ...

# %%
manga.head()
# Out:
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.47
# 1        13                                        One Piece  manga   9.22
# 2      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.30
# 3      4632                                   Oyasumi Punpun  manga   9.02
# 4        25                              Fullmetal Alchemist  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     319696  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     355375  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     151433              finished     24.0      96.0  2004-01-19  2011-04-19
# 3     168459              finished     13.0     147.0  2007-03-15  2013-11-02
# 4     153151              finished     27.0     116.0  2001-07-12  2010-09-11
#
#    ...           demographics  \
# ...

# %%
manga['genres'].unique
# Out:
# <bound method Series.unique of 0        ['Action', 'Adventure', 'Award Winning', 'Dram...
# 1                       ['Action', 'Adventure', 'Fantasy']
# 2        ['Action', 'Adventure', 'Mystery', 'Supernatur...
# 3                               ['Drama', 'Slice of Life']
# 4        ['Action', 'Adventure', 'Award Winning', 'Dram...
#                                ...
# 64828                          ['Romance', 'Supernatural']
# 64829                           ['Comedy', 'Supernatural']
# 64830                          ['Romance', 'Supernatural']
# 64831                                           ['Comedy']
# 64832                                 ['Action', 'Sci-Fi']
# Name: genres, Length: 64833, dtype: object>

# %%
manga['genres'] = manga['genres'].str.replace('[\[\]\'\"]', '', regex=True)

manga['genres'] = manga['genres'].str.split(',')
manga = manga.explode('genres')
manga['genres'] = manga['genres'].str.split(',')
manga = manga.explode('genres')
manga = manga[~manga['genres'].str.contains('Hentai|Boys Love|Girls Love|Erotica')]

# %%
manga['genres'].value_counts().to_frame('Quantidade')
# Out:
#                 Quantidade
# Comedy               10819
#  Romance             10810
# Action                8910
#  Fantasy              7538
#  Supernatural         6963
# Romance               6066
# Drama                 5354
#  Slice of Life        4134
#  Drama                3949
# Fantasy               3414
#  Comedy               3280
#  Sci-Fi               2844
#  Ecchi                2670
#                       2412
#  Adventure            2208
#  Mystery              1746
# Adventure             1704
# Slice of Life         1021
#  Horror                950
# Ecchi                  899
# Horror                 749
# Mystery                695
#  Sports                648
# Supernatural           508
# Sports                 468
#  Suspense              426
# Sci-Fi                 387
# Award Winning          342
#  Gourmet               236
# Gourmet                174
#  Award Winning          97
# Suspense                93
# Avant Garde             59
# ...

# %%
manga['genres'].value_counts()[:10].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Grafico

# %%
anime['score'].hist(bins=11,figsize=(7,7),color='r');

# %% [markdown]
# Area de Teste

# %%
movie['genres'] = movie['genres'].str.split(', ')

# %%
def recommend_movies_by_genre(input_genre, num_recommendations=5):
    # Filtrar filmes que têm o gênero de entrada
    filtered_movies = movie[movie['genres'].apply(lambda x: input_genre in x if isinstance(x, list) else False)]

    if filtered_movies.empty:
        print(f"Nenhum filme encontrado no gênero '{input_genre}'")
        return

    # Ordenar os filmes por alguma métrica (por exemplo, popularidade ou classificação) e obter os 5 melhores
    recommended_movies = filtered_movies.sort_values(by='popularity', ascending=False).head(num_recommendations)

    return recommended_movies

# Teste o sistema de recomendação com um gênero de filme de entrada
input_genre = 'Drama'  # Substitua pelo gênero de interesse
recommendations = recommend_movies_by_genre(input_genre)

if recommendations is not None:
    print(f"Recomendações de filmes no gênero '{input_genre}':")
    print(recommendations[['title', 'popularity', 'adult']])
# Out:
# Recomendações de filmes no gênero 'Drama':
#                                                     title  popularity  adult
# 5049                                         Gran Turismo    2680.593  False
# 51579   A Female Boss with Big Tits and Her Cherry Boy...    2020.286   True
# 6398                                     Sound of Freedom    1111.036  False
# 218540  Incest Mother Sister W Azumi Kinoshita Okita A...     803.324   True
# 75494   Class Reunion Cuckolding - My Beloved Wife And...     759.744   True

# %%
def recommend_movies_by_genre(input_genre, min_popularity=5000,num_recommendations=5, exclude_adult=True):
    # Filtrar filmes que têm o gênero de entrada
    filtered_movies = movie[movie['genres'].apply(lambda x: input_genre in x if isinstance(x, list) else False)]

    if exclude_adult:
        # Excluir filmes para maiores de 18 anos
        filtered_movies = filtered_movies[filtered_movies['adult'] == False]

    if filtered_movies.empty:
        print(f"Nenhum filme encontrado no gênero '{input_genre}'")
        return

    # Ordenar os filmes por alguma métrica (por exemplo, popularidade ou classificação) e obter os 5 melhores
    recommended_movies = filtered_movies.sort_values(by='popularity', ascending=False).head(num_recommendations)

    return recommended_movies

# Teste o sistema de recomendação com um gênero de filme de entrada
input_genre = 'Action'  # Substitua pelo gênero de interesse
recommendations = recommend_movies_by_genre(input_genre)

if recommendations is not None:
    print(f"Recomendações de filmes no gênero '{input_genre}':")
    print(recommendations[['title', 'popularity', 'adult']])
# Out:
# Nenhum filme encontrado no gênero 'Action'

# %%
import random

def recommend_movies_by_genre(input_genre, min_popularity=5000, num_recommendations=5, exclude_adult=True):
    # Filtrar filmes que têm o gênero de entrada
    filtered_movies = movie[movie['genres'].apply(lambda x: input_genre in x if isinstance(x, list) else False)]

    if filtered_movies.empty:
        print(f"Nenhum filme encontrado no gênero '{input_genre}'")
        return

    if exclude_adult:
        # Excluir filmes para maiores de 18 anos
        filtered_movies = filtered_movies[filtered_movies['adult'] == False]

    if filtered_movies.empty:
        print(f"Nenhum filme encontrado no gênero '{input_genre}' lançado após {release_date}")
        return

    sorted_movies = filtered_movies.sort_values(by='popularity', ascending=False)

    # Aleatorizar a ordem dos filmes recomendados
    recommended_movies = filtered_movies.sample(frac=1).head(num_recommendations)

    # Dicionário de gêneros com números de seleção
genre_dict = {
    1: 'Action',2: 'Drama',3: 'Fantasy',4: 'Documentary',5: 'Comedy',6: 'Animation',7: 'Romance',8: 'Horror',9: 'Thriller',10: 'Crime',11: 'Music',12: 'TV Movie',13: 'Family',14: 'Adventure',15: 'Mystery',16: 'History',17: 'Science Fiction',18: 'War',19: 'Western',
    # Adicione mais gêneros conforme necessário
}

# Solicitar ao usuário que escolha um gênero
print("Selecione um gênero:")
for num, genre in genre_dict.items():
    print(f"{num}. {genre}")

selected_genre = None
while selected_genre not in genre_dict:
    try:
        selected_genre = int(input("Digite o número do gênero desejado: "))
    except ValueError:
        pass

input_genre = genre_dict[selected_genre]

# Chame a função de recomendação com o gênero selecionado
recommendations = recommend_movies_by_genre(input_genre)

if recommendations is not None:
    print(f"Recomendações de filmes no gênero '{input_genre}':")
    print(recommendations[['title', 'popularity']])
# Out:
# Selecione um gênero:
# 1. Action
# 2. Drama
# 3. Fantasy
# 4. Documentary
# 5. Comedy
# 6. Animation
# 7. Romance
# 8. Horror
# 9. Thriller
# 10. Crime
# 11. Music
# 12. TV Movie
# 13. Family
# 14. Adventure
# 15. Mystery
# 16. History
# 17. Science Fiction
# 18. War
# 19. Western
# Digite o número do gênero desejado: 18

# %%
movie['genres'] = movie['genres'].str.split(', ')

# %%
import random

def recommend_movies_by_genre(input_genre, min_popularity=5000,num_recommendations=5, exclude_adult=True):
    # Filtrar filmes que têm o gênero de entrada
    filtered_movies = movie[movie['genres'].apply(lambda x: input_genre in x if isinstance(x, list) else False)]

    if exclude_adult:
        filtered_movies = filtered_movies[filtered_movies['adult'] == False]

    if filtered_movies.empty:
        print(f"Nenhum filme encontrado no gênero '{input_genre}'")
        return

    # Ordenar os filmes por alguma métrica (por exemplo, popularidade ou classificação) e obter os 5 melhores
    recommended_movies = filtered_movies.sort_values(by='popularity', ascending=False).head(num_recommendations)

    return recommended_movies
# Dicionário de gêneros com números de seleção
genre_dict = {
    1: 'Action',2: 'Drama',3: 'Fantasy',4: 'Documentary',5: 'Comedy',6: 'Animation',7: 'Romance',8: 'Horror',9: 'Thriller',10: 'Crime',11: 'Music',12: 'TV Movie',13: 'Family',14: 'Adventure',15: 'Mystery',16: 'History',17: 'Science Fiction',18: 'War',19: 'Western',
    # Adicione mais gêneros conforme necessário
}

# Solicitar ao usuário que escolha um gênero
print("Selecione um gênero:")
for num, genre in genre_dict.items():
    print(f"{num}. {genre}")

selected_genre = None
while selected_genre not in genre_dict:
    try:
        selected_genre = int(input("\n Digite o número do gênero desejado: "))
    except ValueError:
        pass

input_genre = genre_dict[selected_genre]

# Chame a função de recomendação com o gênero selecionado
recommendations = recommend_movies_by_genre(input_genre)

if recommendations is not None:
    print(f"=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=\nRecomendações de filmes no gênero '{input_genre}':")
    print(recommendations[['title', 'popularity']])
# Out:
# Selecione um gênero:
# 1. Action
# 2. Drama
# 3. Fantasy
# 4. Documentary
# 5. Comedy
# 6. Animation
# 7. Romance
# 8. Horror
# 9. Thriller
# 10. Crime
# 11. Music
# 12. TV Movie
# 13. Family
# 14. Adventure
# 15. Mystery
# 16. History
# 17. Science Fiction
# 18. War
# 19. Western
#
#  Digite o número do gênero desejado: 18
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Recomendações de filmes no gênero 'War':
#                                            title  popularity
# 66434                                     Bunker     339.829
# 5108                                    Red Dawn     300.738
# 19555  Creation of the Gods I: Kingdom of Storms     254.998
# 12565                               Warhorse One     230.210
# 2580                  Guy Ritchie's The Covenant     188.559
